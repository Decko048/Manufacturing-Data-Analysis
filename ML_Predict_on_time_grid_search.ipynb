# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math 
from matplotlib.figure import Figure
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\mpersonius\anaconda\lib\site-packages (2.4.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\mpersonius\anaconda\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\mpersonius\anaconda\lib\site-packages (from category_encoders) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\mpersonius\anaconda\lib\site-packages (from category_encoders) (0.24.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\mpersonius\anaconda\lib\site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: pandas>=0.21.1 in c:\users\mpersonius\anaconda\lib\site-packages (from category_encoders) (1.3.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\mpersonius\anaconda\lib\site-packages (from category_encoders) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mpersonius\anaconda\lib\site-packages (from pandas>=0.21.1->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mpersonius\anaconda\lib\site-packages (from pandas>=0.21.1->category_encoders) (2021.3)
# Requirement already satisfied: six in c:\users\mpersonius\anaconda\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\mpersonius\anaconda\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mpersonius\anaconda\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)

# %%
import category_encoders as ce

# %%
transpose=pd.read_excel('transpose.xlsx')

# %%
transpose
# Out:
#     Week 1 Unnamed: 1 Unnamed: 2 Unnamed: 3  Week 2 Unnamed: 5 Unnamed: 6  \
# 0   Output  Total Hrs   Wks Load     Week 1  Output  Total Hrs   Wks Load
# 1      113        600   5.309735        112     113        613   5.424779
# 2      418       1880   4.497608        561     418       1831   4.380383
# 3      248       1257   5.068548        384     248       1302       5.25
# 4      154       1152   7.480519        275     148       1185   8.006757
# 5      153        364   2.379085        115     153        430   2.810458
# 6       60        209   3.483333         96      60        233   3.883333
# 7       37        129   3.486486          2      37        106   2.864865
# 8       96        452   4.708333        192      96        514   5.354167
# 9      281        926   3.295374        328     281        936   3.330961
# 10       0          0          -          0       0          0        NaN
# 11     446       2938   6.587444       1341     444       2882   6.490991
# 12    2006       9907   4.938684       3406    1998      10032   5.021021
#
#    Unnamed: 7  Week 3 Unnamed: 9  ... Unnamed: 266 Unnamed: 267 Week 17.1  \
# 0      Week 1  Output  Total Hrs  ...     Wks Load       Week 1    Output
# 1         193     100        686  ...     3.098583      142.532        72
# 2         637     415       1875  ...     3.021027       852.97       514
# 3         434     228       1361  ...     3.111677      342.641       362
# 4         316     165       1377  ...     3.400683      253.545       224
# 5         128     137        581  ...     3.497935      203.628       184
# 6          94      62        218  ...     1.746054       26.196       112
# 7           3      41        120  ...      20.0505        13.54         2
# 8         204      94        529  ...     1.264667       95.571       132
# 9         425     261        890  ...     2.384059      383.531       341
# 10          0       0          0  ...          NaN          NaN       NaN
# 11       1431     449       2769  ...     4.761065       214.42       108
# 12       3865    1952      10406  ...     2.943667     2528.574      2051
#
#    Unnamed: 269 Unnamed: 270 Unnamed: 271 Week 18.1 Unnamed: 273 Unnamed: 274  \
# 0     Total Hrs     Wks Load       Week 1    Output    Total Hrs     Wks Load
# 1        212.71     2.954306      134.236        71      224.464     3.161465
# 2       1877.82     3.653346     1075.773       484     1859.677     3.842308
# 3      1229.508     3.396431      352.771       348     1385.349     3.980888
# 4       793.484     3.542339      224.769       215      821.851     3.822563
# 5       678.614      3.68812      185.616       186      720.645     3.874435
# 6       188.288     1.681143       79.361       102      164.717     1.614873
# 7        38.344       19.172        1.915         2       39.833      19.9165
# 8       187.827     1.422932       95.571        27      193.294     7.159037
# 9       927.409     2.719674      359.807       326     1018.063     3.122893
# 10          NaN          NaN          NaN       NaN          NaN          NaN
# 11       574.41     5.318611      222.411       115       619.42     5.386261
# 12     6708.414     3.270802      2732.23      1876     7047.313     3.756563
#
#    Unnamed: 275
# 0        Week 1
# 1       118.185
# 2       915.597
# 3       357.989
# 4       271.371
# 5       262.227
# 6        50.475
# 7         3.715
# 8        90.476
# 9       346.292
# 10          NaN
# 11      231.035
# 12     2647.362
#
# [13 rows x 276 columns]

# %%
check=transpose.T

# %%
check
# Out:
#                      0         1         2         3         4         5   \
# Week 1           Output       113       418       248       154       153
# Unnamed: 1    Total Hrs       600      1880      1257      1152       364
# Unnamed: 2     Wks Load  5.309735  4.497608  5.068548  7.480519  2.379085
# Unnamed: 3       Week 1       112       561       384       275       115
# Week 2           Output       113       418       248       148       153
# ...                 ...       ...       ...       ...       ...       ...
# Unnamed: 271     Week 1   134.236  1075.773   352.771   224.769   185.616
# Week 18.1        Output        71       484       348       215       186
# Unnamed: 273  Total Hrs   224.464  1859.677  1385.349   821.851   720.645
# Unnamed: 274   Wks Load  3.161465  3.842308  3.980888  3.822563  3.874435
# Unnamed: 275     Week 1   118.185   915.597   357.989   271.371   262.227
#
#                     6         7         8         9    10        11        12
# Week 1              60        37        96       281    0       446      2006
# Unnamed: 1         209       129       452       926    0      2938      9907
# Unnamed: 2    3.483333  3.486486  4.708333  3.295374    -  6.587444  4.938684
# Unnamed: 3          96         2       192       328    0      1341      3406
# Week 2              60        37        96       281    0       444      1998
# ...                ...       ...       ...       ...  ...       ...       ...
# Unnamed: 271    79.361     1.915    95.571   359.807  NaN   222.411   2732.23
# Week 18.1          102         2        27       326  NaN       115      1876
# Unnamed: 273   164.717    39.833   193.294  1018.063  NaN    619.42  7047.313
# Unnamed: 274  1.614873   19.9165  7.159037  3.122893  NaN  5.386261  3.756563
# Unnamed: 275    50.475     3.715    90.476   346.292  NaN   231.035  2647.362
#
# [276 rows x 13 columns]

# %%
check.to_excel('check.xls')
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3269339652.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   check.to_excel('check.xls')

# %%
loop21=pd.read_excel('load_history.xls', sheet_name= 'Sheet1')

# %%
loop21
# Out:
#      Year  Week      Title        Value
# 0      21     1     Output  2006.000000
# 1      21     1  Total Hrs  9907.000000
# 2      21     1   Wks Load     4.938684
# 3      21     1     Week 1  3406.000000
# 4      21     2     Output  1998.000000
# ..    ...   ...        ...          ...
# 199    21    50     Week 1  2893.000000
# 200    21    51     Output  1980.000000
# 201    21    51  Total Hrs  7048.000000
# 202    21    51   Wks Load     3.559596
# 203    21    51     Week 1  3126.000000
#
# [204 rows x 4 columns]

# %%
output_21=loop21.iloc[::4, :]
output_21['created_yr']=output_21['Year']
output_21['created_wk']=output_21['Week']
output_21
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3921137354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_21['created_yr']=output_21['Year']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3921137354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_21['created_wk']=output_21['Week']
#      Year  Week   Title   Value  created_yr  created_wk
# 0      21     1  Output  2006.0          21           1
# 4      21     2  Output  1998.0          21           2
# 8      21     3  Output  1952.0          21           3
# 12     21     4  Output  2139.0          21           4
# 16     21     5  Output  2155.0          21           5
# 20     21     6  Output  2098.0          21           6
# 24     21     7  Output  2105.0          21           7
# 28     21     8  Output  2200.0          21           8
# 32     21     9  Output  2199.0          21           9
# 36     21    10  Output  2192.0          21          10
# 40     21    11  Output  2177.0          21          11
# 44     21    12  Output  2185.0          21          12
# 48     21    13  Output  2166.0          21          13
# 52     21    14  Output  2148.0          21          14
# 56     21    15  Output  2151.0          21          15
# 60     21    16  Output  2134.0          21          16
# 64     21    17  Output  2167.0          21          17
# 68     21    18  Output  2110.0          21          18
# 72     21    19  Output  2118.0          21          19
# 76     21    20  Output  2116.0          21          20
# 80     21    21  Output  2130.0          21          21
# 84     21    22  Output  2127.0          21          22
# 88     21    23  Output  2155.0          21          23
# 92     21    24  Output  2155.0          21          24
# 96     21    25  Output  2182.0          21          25
# 100    21    26  Output  2175.0          21          26
# 104    21    27  Output  2109.0          21          27
# 108    21    28  Output  2155.0          21          28
# 112    21    29  Output  1938.0          21          29
# 116    21    30  Output  1836.0          21          30
# 120    21    31  Output  1761.0          21          31
# 124    21    32  Output  1678.0          21          32
# 128    21    33  Output  1716.0          21          33
# 132    21    34  Output  1626.0          21          34
# 136    21    35  Output  1592.0          21          35
# 140    21    36  Output  1603.0          21          36
# 144    21    37  Output  1639.0          21          37
# 148    21    38  Output  1639.0          21          38
# 152    21    39  Output  1647.0          21          39
# 156    21    40  Output  1670.0          21          40
# 160    21    41  Output  1742.0          21          41
# 164    21    42  Output  1762.0          21          42
# 168    21    43  Output  1811.0          21          43
# 172    21    44  Output  1839.0          21          44
# 176    21    45  Output  1893.0          21          45
# 180    21    46  Output  1857.0          21          46
# 184    21    47  Output  1877.0          21          47
# 188    21    48  Output  1868.0          21          48
# 192    21    49  Output  1860.0          21          49
# 196    21    50  Output  1917.0          21          50
# 200    21    51  Output  1980.0          21          51

# %%
total_hrs21=loop21.iloc[1::4, :]
total_hrs21['created_yr']=total_hrs21['Year']
total_hrs21['created_wk']=total_hrs21['Week']
total_hrs21
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/640738667.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_hrs21['created_yr']=total_hrs21['Year']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/640738667.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_hrs21['created_wk']=total_hrs21['Week']
#      Year  Week      Title    Value  created_yr  created_wk
# 1      21     1  Total Hrs   9907.0          21           1
# 5      21     2  Total Hrs  10032.0          21           2
# 9      21     3  Total Hrs  10406.0          21           3
# 13     21     4  Total Hrs  10602.0          21           4
# 17     21     5  Total Hrs  10671.0          21           5
# 21     21     6  Total Hrs  10621.0          21           6
# 25     21     7  Total Hrs   9535.0          21           7
# 29     21     8  Total Hrs   9853.0          21           8
# 33     21     9  Total Hrs  10293.0          21           9
# 37     21    10  Total Hrs  10184.0          21          10
# 41     21    11  Total Hrs  10059.0          21          11
# 45     21    12  Total Hrs  10356.0          21          12
# 49     21    13  Total Hrs  11249.0          21          13
# 53     21    14  Total Hrs  11282.0          21          14
# 57     21    15  Total Hrs  11151.0          21          15
# 61     21    16  Total Hrs  11220.0          21          16
# 65     21    17  Total Hrs  10676.0          21          17
# 69     21    18  Total Hrs  10190.0          21          18
# 73     21    19  Total Hrs   9459.0          21          19
# 77     21    20  Total Hrs   8780.0          21          20
# 81     21    21  Total Hrs   8664.0          21          21
# 85     21    22  Total Hrs   8474.0          21          22
# 89     21    23  Total Hrs   9059.0          21          23
# 93     21    24  Total Hrs   9059.0          21          24
# 97     21    25  Total Hrs   9048.0          21          25
# 101    21    26  Total Hrs   9775.0          21          26
# 105    21    27  Total Hrs   9971.0          21          27
# 109    21    28  Total Hrs   9059.0          21          28
# 113    21    29  Total Hrs   9986.0          21          29
# 117    21    30  Total Hrs  10011.0          21          30
# 121    21    31  Total Hrs   9819.0          21          31
# 125    21    32  Total Hrs   9431.0          21          32
# 129    21    33  Total Hrs   8804.0          21          33
# 133    21    34  Total Hrs   9338.0          21          34
# 137    21    35  Total Hrs   9383.0          21          35
# 141    21    36  Total Hrs   9117.0          21          36
# 145    21    37  Total Hrs   9304.0          21          37
# 149    21    38  Total Hrs   9554.0          21          38
# 153    21    39  Total Hrs   8704.0          21          39
# 157    21    40  Total Hrs   8640.0          21          40
# 161    21    41  Total Hrs   8525.0          21          41
# 165    21    42  Total Hrs   7899.0          21          42
# 169    21    43  Total Hrs   7851.0          21          43
# 173    21    44  Total Hrs   8018.0          21          44
# 177    21    45  Total Hrs   7584.0          21          45
# 181    21    46  Total Hrs   7753.0          21          46
# 185    21    47  Total Hrs   7261.0          21          47
# 189    21    48  Total Hrs   6835.0          21          48
# 193    21    49  Total Hrs   6822.0          21          49
# 197    21    50  Total Hrs   6590.0          21          50
# 201    21    51  Total Hrs   7048.0          21          51

# %%
wks_load21=loop21.iloc[2::4, :]
wks_load21['created_yr']=wks_load21['Year'].astype(str)
wks_load21['created_wk']=wks_load21['Week'].astype(str)
wks_load21
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/2981666504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wks_load21['created_yr']=wks_load21['Year'].astype(str)
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/2981666504.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wks_load21['created_wk']=wks_load21['Week'].astype(str)
#      Year  Week     Title     Value created_yr created_wk
# 2      21     1  Wks Load  4.938684         21          1
# 6      21     2  Wks Load  5.021021         21          2
# 10     21     3  Wks Load  5.330943         21          3
# 14     21     4  Wks Load  4.956522         21          4
# 18     21     5  Wks Load  4.951740         21          5
# 22     21     6  Wks Load  5.062440         21          6
# 26     21     7  Wks Load  4.529691         21          7
# 30     21     8  Wks Load  4.478636         21          8
# 34     21     9  Wks Load  4.680764         21          9
# 38     21    10  Wks Load  4.645985         21         10
# 42     21    11  Wks Load  4.620579         21         11
# 46     21    12  Wks Load  4.739588         21         12
# 50     21    13  Wks Load  5.193444         21         13
# 54     21    14  Wks Load  5.252328         21         14
# 58     21    15  Wks Load  5.184100         21         15
# 62     21    16  Wks Load  5.257732         21         16
# 66     21    17  Wks Load  4.926627         21         17
# 70     21    18  Wks Load  4.829384         21         18
# 74     21    19  Wks Load  4.466006         21         19
# 78     21    20  Wks Load  4.149338         21         20
# 82     21    21  Wks Load  4.067606         21         21
# 86     21    22  Wks Load  3.984015         21         22
# 90     21    23  Wks Load  4.203712         21         23
# 94     21    24  Wks Load  4.203712         21         24
# 98     21    25  Wks Load  4.146654         21         25
# 102    21    26  Wks Load  4.494253         21         26
# 106    21    27  Wks Load  4.727833         21         27
# 110    21    28  Wks Load  4.203712         21         28
# 114    21    29  Wks Load  5.152735         21         29
# 118    21    30  Wks Load  5.452614         21         30
# 122    21    31  Wks Load  5.575809         21         31
# 126    21    32  Wks Load  5.620381         21         32
# 130    21    33  Wks Load  5.130536         21         33
# 134    21    34  Wks Load  5.742927         21         34
# 138    21    35  Wks Load  5.893844         21         35
# 142    21    36  Wks Load  5.687461         21         36
# 146    21    37  Wks Load  5.676632         21         37
# 150    21    38  Wks Load  5.829164         21         38
# 154    21    39  Wks Load  5.284760         21         39
# 158    21    40  Wks Load  5.173653         21         40
# 162    21    41  Wks Load  4.893800         21         41
# 166    21    42  Wks Load  4.482974         21         42
# 170    21    43  Wks Load  4.335174         21         43
# 174    21    44  Wks Load  4.359978         21         44
# 178    21    45  Wks Load  4.006339         21         45
# 182    21    46  Wks Load  4.175013         21         46
# 186    21    47  Wks Load  3.868407         21         47
# 190    21    48  Wks Load  3.658994         21         48
# 194    21    49  Wks Load  3.667742         21         49
# 198    21    50  Wks Load  3.437663         21         50
# 202    21    51  Wks Load  3.559596         21         51

# %%
week_one21=loop21.iloc[3::4, :]
week_one21['created_yr']=week_one21['Year']
week_one21['created_wk']=week_one21['Week']
week_one21
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/1756724557.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_one21['created_yr']=week_one21['Year']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/1756724557.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_one21['created_wk']=week_one21['Week']
#      Year  Week   Title   Value  created_yr  created_wk
# 3      21     1  Week 1  3406.0          21           1
# 7      21     2  Week 1  3865.0          21           2
# 11     21     3  Week 1  3879.0          21           3
# 15     21     4  Week 1  3764.0          21           4
# 19     21     5  Week 1  3498.0          21           5
# 23     21     6  Week 1  3509.0          21           6
# 27     21     7  Week 1  3022.0          21           7
# 31     21     8  Week 1  2966.0          21           8
# 35     21     9  Week 1  3327.0          21           9
# 39     21    10  Week 1  3681.0          21          10
# 43     21    11  Week 1  4035.0          21          11
# 47     21    12  Week 1  3799.0          21          12
# 51     21    13  Week 1  3416.0          21          13
# 55     21    14  Week 1  3832.0          21          14
# 59     21    15  Week 1  3860.0          21          15
# 63     21    16  Week 1  4166.0          21          16
# 67     21    17  Week 1  4605.0          21          17
# 71     21    18  Week 1  4398.0          21          18
# 75     21    19  Week 1  4243.0          21          19
# 79     21    20  Week 1  3920.0          21          20
# 83     21    21  Week 1  3602.0          21          21
# 87     21    22  Week 1  3031.0          21          22
# 91     21    23  Week 1  3351.0          21          23
# 95     21    24  Week 1  3351.0          21          24
# 99     21    25  Week 1  3940.0          21          25
# 103    21    26  Week 1  3834.0          21          26
# 107    21    27  Week 1  4382.0          21          27
# 111    21    28  Week 1  3351.0          21          28
# 115    21    29  Week 1  4372.0          21          29
# 119    21    30  Week 1  4318.0          21          30
# 123    21    31  Week 1  3952.0          21          31
# 127    21    32  Week 1  4454.0          21          32
# 131    21    33  Week 1  4297.0          21          33
# 135    21    34  Week 1  4278.0          21          34
# 139    21    35  Week 1  4479.0          21          35
# 143    21    36  Week 1  3827.0          21          36
# 147    21    37  Week 1  4282.0          21          37
# 151    21    38  Week 1  4289.0          21          38
# 155    21    39  Week 1  4052.0          21          39
# 159    21    40  Week 1  4039.0          21          40
# 163    21    41  Week 1  4075.0          21          41
# 167    21    42  Week 1  3738.0          21          42
# 171    21    43  Week 1  3460.0          21          43
# 175    21    44  Week 1  3740.0          21          44
# 179    21    45  Week 1  3751.0          21          45
# 183    21    46  Week 1  4029.0          21          46
# 187    21    47  Week 1  3723.0          21          47
# 191    21    48  Week 1  3553.0          21          48
# 195    21    49  Week 1  3218.0          21          49
# 199    21    50  Week 1  2893.0          21          50
# 203    21    51  Week 1  3126.0          21          51

# %%
loop22=pd.read_excel('load_history.xls', sheet_name= 'Sheet2')

# %%
loop22
# Out:
#     Year  Week      Title        Value
# 0     22     1     Output  1879.000000
# 1     22     1  Total Hrs  7514.000000
# 2     22     1   Wks Load     3.998936
# 3     22     1     Week 1  3416.000000
# 4     22     2     Output  1879.000000
# ..   ...   ...        ...          ...
# 67    22    17     Week 1  2732.230000
# 68    22    18     Output  1876.000000
# 69    22    18  Total Hrs  7047.313000
# 70    22    18   Wks Load     3.756563
# 71    22    18     Week 1  2647.362000
#
# [72 rows x 4 columns]

# %%
output_22=loop22.iloc[::4, :]
output_22['created_yr']=output_22['Year'].astype(str)
output_22['created_wk']=output_22['Week'].astype(str)
output_22
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/4028169709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_22['created_yr']=output_22['Year'].astype(str)
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/4028169709.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_22['created_wk']=output_22['Week'].astype(str)
#     Year  Week   Title   Value created_yr created_wk
# 0     22     1  Output  1879.0         22          1
# 4     22     2  Output  1879.0         22          2
# 8     22     3  Output  1903.0         22          3
# 12    22     4  Output  1882.0         22          4
# 16    22     5  Output  1772.0         22          5
# 20    22     6  Output  1714.0         22          6
# 24    22     7  Output  1794.0         22          7
# 28    22     8  Output  1853.0         22          8
# 32    22     9  Output  1809.0         22          9
# 36    22    10  Output  1798.0         22         10
# 40    22    11  Output  1804.0         22         11
# 44    22    12  Output  1830.0         22         12
# 48    22    13  Output  1852.0         22         13
# 52    22    14  Output  1883.0         22         14
# 56    22    15  Output  1964.0         22         15
# 60    22    16  Output  2051.0         22         16
# 64    22    17  Output  2051.0         22         17
# 68    22    18  Output  1876.0         22         18

# %%
total_hrs22=loop22.iloc[1::4, :]
total_hrs22['created_yr']=total_hrs22['Year'].astype(str)
total_hrs22['created_wk']=total_hrs22['Week'].astype(str)
total_hrs22
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/4059180549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_hrs22['created_yr']=total_hrs22['Year'].astype(str)
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/4059180549.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_hrs22['created_wk']=total_hrs22['Week'].astype(str)
#     Year  Week      Title     Value created_yr created_wk
# 1     22     1  Total Hrs  7514.000         22          1
# 5     22     2  Total Hrs  7405.000         22          2
# 9     22     3  Total Hrs  7653.000         22          3
# 13    22     4  Total Hrs  7877.000         22          4
# 17    22     5  Total Hrs  7874.000         22          5
# 21    22     6  Total Hrs  7567.803         22          6
# 25    22     7  Total Hrs  7467.285         22          7
# 29    22     8  Total Hrs  7330.995         22          8
# 33    22     9  Total Hrs  7071.089         22          9
# 37    22    10  Total Hrs  7295.650         22         10
# 41    22    11  Total Hrs  7071.302         22         11
# 45    22    12  Total Hrs  6745.384         22         12
# 49    22    13  Total Hrs  6780.892         22         13
# 53    22    14  Total Hrs  6365.243         22         14
# 57    22    15  Total Hrs  6228.258         22         15
# 61    22    16  Total Hrs  6037.460         22         16
# 65    22    17  Total Hrs  6708.414         22         17
# 69    22    18  Total Hrs  7047.313         22         18

# %%
wks_load22=loop22.iloc[2::4, :]
wks_load22['created_yr']=wks_load22['Year'].astype(str)
wks_load22['created_wk']=wks_load22['Week'].astype(str)
wks_load22
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/404893038.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wks_load22['created_yr']=wks_load22['Year'].astype(str)
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/404893038.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wks_load22['created_wk']=wks_load22['Week'].astype(str)
#     Year  Week     Title     Value created_yr created_wk
# 2     22     1  Wks Load  3.998936         22          1
# 6     22     2  Wks Load  3.940926         22          2
# 10    22     3  Wks Load  4.021545         22          3
# 14    22     4  Wks Load  4.185441         22          4
# 18    22     5  Wks Load  4.443567         22          5
# 22    22     6  Wks Load  4.415288         22          6
# 26    22     7  Wks Load  4.162366         22          7
# 30    22     8  Wks Load  3.956284         22          8
# 34    22     9  Wks Load  3.908839         22          9
# 38    22    10  Wks Load  4.057647         22         10
# 42    22    11  Wks Load  3.919790         22         11
# 46    22    12  Wks Load  3.686002         22         12
# 50    22    13  Wks Load  3.661389         22         13
# 54    22    14  Wks Load  3.380373         22         14
# 58    22    15  Wks Load  3.171211         22         15
# 62    22    16  Wks Load  2.943667         22         16
# 66    22    17  Wks Load  3.270802         22         17
# 70    22    18  Wks Load  3.756563         22         18

# %%
week_one22=loop22.iloc[3::4, :]
week_one22['created_yr']=week_one22['Year'].astype(str)
week_one22['created_wk']=week_one22['Week'].astype(str)
week_one22
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/4181413993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_one22['created_yr']=week_one22['Year'].astype(str)
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/4181413993.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_one22['created_wk']=week_one22['Week'].astype(str)
#     Year  Week   Title     Value created_yr created_wk
# 3     22     1  Week 1  3416.000         22          1
# 7     22     2  Week 1  3205.000         22          2
# 11    22     3  Week 1  3817.000         22          3
# 15    22     4  Week 1  3829.000         22          4
# 19    22     5  Week 1  3945.000         22          5
# 23    22     6  Week 1  3394.959         22          6
# 27    22     7  Week 1  3354.812         22          7
# 31    22     8  Week 1  3296.079         22          8
# 35    22     9  Week 1  3275.335         22          9
# 39    22    10  Week 1  3313.141         22         10
# 43    22    11  Week 1  3232.652         22         11
# 47    22    12  Week 1  3023.877         22         12
# 51    22    13  Week 1  3194.801         22         13
# 55    22    14  Week 1  2606.766         22         14
# 59    22    15  Week 1  2594.637         22         15
# 63    22    16  Week 1  2528.574         22         16
# 67    22    17  Week 1  2732.230         22         17
# 71    22    18  Week 1  2647.362         22         18

# %%
wks_load21['wks_load']=wks_load21['Value']
wks_load22['wks_load']=wks_load22['Value']
frames = [wks_load21, wks_load22]
wks_load= pd.concat(frames)


week_one21['single_week']=week_one21['Value']
week_one22['single_week']=week_one22['Value']
frames = [week_one21, week_one22]
wk_one= pd.concat(frames)


output_21['avg_output']=output_21['Value']
output_22['avg_output']=output_22['Value']
frames = [output_21, output_22]
output= pd.concat(frames)

total_hrs21['Total Hrs']=total_hrs21['Value']
total_hrs22['Total Hrs']=total_hrs22['Value']
frames = [total_hrs21, total_hrs22]
total_hrs= pd.concat(frames)

wks_load
wk_one
output
total_hrs
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3680864695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wks_load21['wks_load']=wks_load21['Value']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3680864695.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wks_load22['wks_load']=wks_load22['Value']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3680864695.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_one21['single_week']=week_one21['Value']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3680864695.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_one22['single_week']=week_one22['Value']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3680864695.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_21['avg_output']=output_21['Value']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3680864695.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_22['avg_output']=output_22['Value']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3680864695.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_hrs21['Total Hrs']=total_hrs21['Value']
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3680864695.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_hrs22['Total Hrs']=total_hrs22['Value']
#     Year  Week      Title      Value created_yr created_wk  Total Hrs
# 1     21     1  Total Hrs   9907.000         21          1   9907.000
# 5     21     2  Total Hrs  10032.000         21          2  10032.000
# 9     21     3  Total Hrs  10406.000         21          3  10406.000
# 13    21     4  Total Hrs  10602.000         21          4  10602.000
# 17    21     5  Total Hrs  10671.000         21          5  10671.000
# ..   ...   ...        ...        ...        ...        ...        ...
# 53    22    14  Total Hrs   6365.243         22         14   6365.243
# 57    22    15  Total Hrs   6228.258         22         15   6228.258
# 61    22    16  Total Hrs   6037.460         22         16   6037.460
# 65    22    17  Total Hrs   6708.414         22         17   6708.414
# 69    22    18  Total Hrs   7047.313         22         18   7047.313
#
# [69 rows x 7 columns]

# %%
output
# Out:
#     Year  Week   Title   Value created_yr created_wk  avg_output
# 0     21     1  Output  2006.0         21          1      2006.0
# 4     21     2  Output  1998.0         21          2      1998.0
# 8     21     3  Output  1952.0         21          3      1952.0
# 12    21     4  Output  2139.0         21          4      2139.0
# 16    21     5  Output  2155.0         21          5      2155.0
# ..   ...   ...     ...     ...        ...        ...         ...
# 52    22    14  Output  1883.0         22         14      1883.0
# 56    22    15  Output  1964.0         22         15      1964.0
# 60    22    16  Output  2051.0         22         16      2051.0
# 64    22    17  Output  2051.0         22         17      2051.0
# 68    22    18  Output  1876.0         22         18      1876.0
#
# [69 rows x 7 columns]

# %%
wk_one
# Out:
#     Year  Week   Title     Value created_yr created_wk  single_week
# 3     21     1  Week 1  3406.000         21          1     3406.000
# 7     21     2  Week 1  3865.000         21          2     3865.000
# 11    21     3  Week 1  3879.000         21          3     3879.000
# 15    21     4  Week 1  3764.000         21          4     3764.000
# 19    21     5  Week 1  3498.000         21          5     3498.000
# ..   ...   ...     ...       ...        ...        ...          ...
# 55    22    14  Week 1  2606.766         22         14     2606.766
# 59    22    15  Week 1  2594.637         22         15     2594.637
# 63    22    16  Week 1  2528.574         22         16     2528.574
# 67    22    17  Week 1  2732.230         22         17     2732.230
# 71    22    18  Week 1  2647.362         22         18     2647.362
#
# [69 rows x 7 columns]

# %%
wks_load.dtypes
# Out:
# Year            int64
# Week            int64
# Title          object
# Value         float64
# created_yr     object
# created_wk     object
# wks_load      float64
# dtype: object

# %%
wks_load.to_excel('wks_load.xls')
wk_one.to_excel('wk_one.xls')
output.to_excel('output.xls')
total_hrs.to_excel('total_hrs.xls')
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/2112820525.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   wks_load.to_excel('wks_load.xls')
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/2112820525.py:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   wk_one.to_excel('wk_one.xls')
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/2112820525.py:3: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   output.to_excel('output.xls')
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/2112820525.py:4: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   total_hrs.to_excel('total_hrs.xls')

# %%
to_merge=pd.read_excel('load_to_merge.xls')

# %%
to_merge['created_yr']=to_merge['created_yr'].astype(str)
to_merge['created_wk']=to_merge['created_wk'].astype(str)

# %%
to_merge
# Out:
#    created_yr created_wk  Total Hrs  single_week  avg_output  wks_load
# 0          21          1   9907.000     3406.000        2006  4.938684
# 1          21          2  10032.000     3865.000        1998  5.021021
# 2          21          3  10406.000     3879.000        1952  5.330943
# 3          21          4  10602.000     3764.000        2139  4.956522
# 4          21          5  10671.000     3498.000        2155  4.951740
# ..        ...        ...        ...          ...         ...       ...
# 64         22         14   6365.243     2606.766        1883  3.380373
# 65         22         15   6228.258     2594.637        1964  3.171211
# 66         22         16   6037.460     2528.574        2051  2.943667
# 67         22         17   6708.414     2732.230        2051  3.270802
# 68         22         18   7047.313     2647.362        1876  3.756563
#
# [69 rows x 6 columns]

# %%
D49=pd.read_excel('WO_History_-_D49.xls', skiprows=1)

# %%
D49
# Out:
#      DEPT  B/P    CREATED     DUE DT DT COMPLETED   WO NBR      PART NUMBER  \
# 0     D49  X67 2021-01-05 2020-12-22   2021-01-13  5150820    BG-17E10-40EN
# 1     D49  X66 2021-01-05 2021-04-28   2021-03-05  5150870    BG-19E10-10EN
# 2     D49  X20 2021-01-05 2021-02-17   2021-02-19  5151400  BT192220EN-Y240
# 3     D49  X66 2021-01-05 2021-07-31   2021-01-21  5151360    F2-660320-013
# 4     D49  F45 2021-01-05 2021-01-15   2021-01-12  5151430   M10-660174-13B
# ...   ...  ...        ...        ...          ...      ...              ...
# 7303  D49  P56 2022-04-28 2022-05-31          NaT  3077420    10-553318-25G
# 7304  D49  X20 2022-04-28 2022-10-31          NaT  3076580    10-706969-008
# 7305  D49  XRS 2022-04-28 2022-05-17          NaT  3076540    21-091912-001
# 7306  D49  F46 2022-04-28 2021-11-11          NaT  3078910    21-120429-239
# 7307  D49  X20 2022-04-29 2022-10-31          NaT  3088270    BT-19E12-20EN
#
#       ORIG QTY  QTY TO STOCK  QTY SCRAP WOTYPE CREATED BY  STS PRIMARY WC  \
# 0           27            22          4      N    B125342   75      X5167
# 1           50            30         10      N    B125342   75      X5163
# 2           50            44          6      N    B125342   70      X5185
# 3           80            23         64      N    B125342   70      X5184
# 4          250           252          1      N    B125342   70      F5184
# ...        ...           ...        ...    ...        ...  ...        ...
# 7303        65             0          0      N    B125342    0      P5128
# 7304        30             0          0      N    B125342    0      X5120
# 7305       109             0          0      N    B125342   10      F5173
# 7306        10             0          0      R   NAX38691   10      F5189
# 7307        15             0          0      R   NAX36785    0      X5185
#
#                            ITEM DESC  SCH DT CHG CNT
# 0                         RCPT SHELL               0
# 1                  RCPT SHELL     -N               0
# 2                         RCPT SHELL               1
# 3     SHELL, PLUG   -ZINC NI      -N               1
# 4                           NUT, HEX               0
# ...                              ...             ...
# 7303                        PROT CAP               0
# 7304              SLEEVE, PLUG -AJ4R               1
# 7305                          INSERT               0
# 7306  SHELL, RCPT   -CAD OD/NI    -A               2
# 7307                RECEPTACLE SHELL               1
#
# [7308 rows x 16 columns]

# %%
# get week column as created_wk and created_yr

# %%
D49['created_yr']=D49['CREATED'].dt.strftime('%y')
D49['created_wk']=D49['CREATED'].dt.week.astype(str)
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/4202057922.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   D49['created_wk']=D49['CREATED'].dt.week.astype(str)

# %%
D49.dtypes
# Out:
# DEPT                      object
# B/P                       object
# CREATED           datetime64[ns]
# DUE DT            datetime64[ns]
# DT COMPLETED      datetime64[ns]
# WO NBR                    object
# PART NUMBER               object
# ORIG QTY                   int64
# QTY TO STOCK               int64
# QTY SCRAP                  int64
# WOTYPE                    object
# CREATED BY                object
# STS                        int64
# PRIMARY WC                object
# ITEM DESC                 object
# SCH DT CHG CNT             int64
# created_yr                object
# created_wk                object
# dtype: object

# %% [markdown]
# ### Need to get first ring date merged on this df and then put week and year to merge

# %% [markdown]
# ### Need to get the critical qty of the order to assist with y/n criteria

# %% [markdown]
# ### Need to define a YES/NO criteria based on percent to stock by certain date, etc

# %%
D49['Days Late']=D49['DT COMPLETED']-D49['DUE DT']
D49['Days Late Int']=D49['Days Late'].dt.days
D49['Possible_time']=D49['DUE DT']-D49['CREATED']
D49['Possible_time']=D49['Possible_time'].dt.days

# %%
D49
# Out:
#      DEPT  B/P    CREATED     DUE DT DT COMPLETED   WO NBR      PART NUMBER  \
# 0     D49  X67 2021-01-05 2020-12-22   2021-01-13  5150820    BG-17E10-40EN
# 1     D49  X66 2021-01-05 2021-04-28   2021-03-05  5150870    BG-19E10-10EN
# 2     D49  X20 2021-01-05 2021-02-17   2021-02-19  5151400  BT192220EN-Y240
# 3     D49  X66 2021-01-05 2021-07-31   2021-01-21  5151360    F2-660320-013
# 4     D49  F45 2021-01-05 2021-01-15   2021-01-12  5151430   M10-660174-13B
# ...   ...  ...        ...        ...          ...      ...              ...
# 7303  D49  P56 2022-04-28 2022-05-31          NaT  3077420    10-553318-25G
# 7304  D49  X20 2022-04-28 2022-10-31          NaT  3076580    10-706969-008
# 7305  D49  XRS 2022-04-28 2022-05-17          NaT  3076540    21-091912-001
# 7306  D49  F46 2022-04-28 2021-11-11          NaT  3078910    21-120429-239
# 7307  D49  X20 2022-04-29 2022-10-31          NaT  3088270    BT-19E12-20EN
#
#       ORIG QTY  QTY TO STOCK  QTY SCRAP  ... CREATED BY STS  PRIMARY WC  \
# 0           27            22          4  ...    B125342  75       X5167
# 1           50            30         10  ...    B125342  75       X5163
# 2           50            44          6  ...    B125342  70       X5185
# 3           80            23         64  ...    B125342  70       X5184
# 4          250           252          1  ...    B125342  70       F5184
# ...        ...           ...        ...  ...        ...  ..         ...
# 7303        65             0          0  ...    B125342   0       P5128
# 7304        30             0          0  ...    B125342   0       X5120
# 7305       109             0          0  ...    B125342  10       F5173
# 7306        10             0          0  ...   NAX38691  10       F5189
# 7307        15             0          0  ...   NAX36785   0       X5185
#
#                            ITEM DESC SCH DT CHG CNT  created_yr created_wk  \
# 0                         RCPT SHELL              0          21          1
# 1                  RCPT SHELL     -N              0          21          1
# 2                         RCPT SHELL              1          21          1
# 3     SHELL, PLUG   -ZINC NI      -N              1          21          1
# 4                           NUT, HEX              0          21          1
# ...                              ...            ...         ...        ...
# 7303                        PROT CAP              0          22         17
# 7304              SLEEVE, PLUG -AJ4R              1          22         17
# 7305                          INSERT              0          22         17
# 7306  SHELL, RCPT   -CAD OD/NI    -A              2          22         17
# 7307                RECEPTACLE SHELL              1          22         17
#
#      Days Late Days Late Int  Possible_time
# 0      22 days          22.0            -14
# 1     -54 days         -54.0            113
# 2       2 days           2.0             43
# 3    -191 days        -191.0            207
# 4      -3 days          -3.0             10
# ...        ...           ...            ...
# 7303       NaT           NaN             33
# 7304       NaT           NaN            186
# 7305       NaT           NaN             19
# 7306       NaT           NaN           -168
# 7307       NaT           NaN            185
#
# [7308 rows x 21 columns]

# %%
D49.dtypes
# Out:
# DEPT                       object
# B/P                        object
# CREATED            datetime64[ns]
# DUE DT             datetime64[ns]
# DT COMPLETED       datetime64[ns]
# WO NBR                     object
# PART NUMBER                object
# ORIG QTY                    int64
# QTY TO STOCK                int64
# QTY SCRAP                   int64
# WOTYPE                     object
# CREATED BY                 object
# STS                         int64
# PRIMARY WC                 object
# ITEM DESC                  object
# SCH DT CHG CNT              int64
# created_yr                 object
# created_wk                 object
# Days Late         timedelta64[ns]
# Days Late Int             float64
# Possible_time               int64
# dtype: object

# %%
wks_load21.dtypes
# Out:
# Year            int64
# Week            int64
# Title          object
# Value         float64
# created_yr     object
# created_wk     object
# wks_load      float64
# dtype: object

# %%
new_df1 = pd.merge(D49, to_merge,  how='outer', on=['created_yr','created_wk'])

# %%
new_df1
# Out:
#      DEPT  B/P    CREATED     DUE DT DT COMPLETED   WO NBR      PART NUMBER  \
# 0     D49  X67 2021-01-05 2020-12-22   2021-01-13  5150820    BG-17E10-40EN
# 1     D49  X66 2021-01-05 2021-04-28   2021-03-05  5150870    BG-19E10-10EN
# 2     D49  X20 2021-01-05 2021-02-17   2021-02-19  5151400  BT192220EN-Y240
# 3     D49  X66 2021-01-05 2021-07-31   2021-01-21  5151360    F2-660320-013
# 4     D49  F45 2021-01-05 2021-01-15   2021-01-12  5151430   M10-660174-13B
# ...   ...  ...        ...        ...          ...      ...              ...
# 7304  D49  X20 2022-04-28 2022-10-31          NaT  3076580    10-706969-008
# 7305  D49  XRS 2022-04-28 2022-05-17          NaT  3076540    21-091912-001
# 7306  D49  F46 2022-04-28 2021-11-11          NaT  3078910    21-120429-239
# 7307  D49  X20 2022-04-29 2022-10-31          NaT  3088270    BT-19E12-20EN
# 7308  NaN  NaN        NaT        NaT          NaT      NaN              NaN
#
#       ORIG QTY  QTY TO STOCK  QTY SCRAP  ... SCH DT CHG CNT created_yr  \
# 0         27.0          22.0        4.0  ...            0.0         21
# 1         50.0          30.0       10.0  ...            0.0         21
# 2         50.0          44.0        6.0  ...            1.0         21
# 3         80.0          23.0       64.0  ...            1.0         21
# 4        250.0         252.0        1.0  ...            0.0         21
# ...        ...           ...        ...  ...            ...        ...
# 7304      30.0           0.0        0.0  ...            1.0         22
# 7305     109.0           0.0        0.0  ...            0.0         22
# 7306      10.0           0.0        0.0  ...            2.0         22
# 7307      15.0           0.0        0.0  ...            1.0         22
# 7308       NaN           NaN        NaN  ...            NaN         22
#
#       created_wk Days Late Days Late Int  Possible_time Total Hrs single_week  \
# 0              1   22 days          22.0          -14.0  9907.000    3406.000
# 1              1  -54 days         -54.0          113.0  9907.000    3406.000
# 2              1    2 days           2.0           43.0  9907.000    3406.000
# 3              1 -191 days        -191.0          207.0  9907.000    3406.000
# 4              1   -3 days          -3.0           10.0  9907.000    3406.000
# ...          ...       ...           ...            ...       ...         ...
# 7304          17       NaT           NaN          186.0  6708.414    2732.230
# 7305          17       NaT           NaN           19.0  6708.414    2732.230
# 7306          17       NaT           NaN         -168.0  6708.414    2732.230
# 7307          17       NaT           NaN          185.0  6708.414    2732.230
# 7308          18       NaT           NaN            NaN  7047.313    2647.362
#
#      avg_output  wks_load
# 0        2006.0  4.938684
# 1        2006.0  4.938684
# 2        2006.0  4.938684
# 3        2006.0  4.938684
# 4        2006.0  4.938684
# ...         ...       ...
# 7304     2051.0  3.270802
# 7305     2051.0  3.270802
# 7306     2051.0  3.270802
# 7307     2051.0  3.270802
# 7308     1876.0  3.756563
#
# [7309 rows x 25 columns]

# %%
new_df1= new_df1[new_df1['Days Late Int'].notna()]

# %%
new_df1
# Out:
#      DEPT  B/P    CREATED     DUE DT DT COMPLETED   WO NBR      PART NUMBER  \
# 0     D49  X67 2021-01-05 2020-12-22   2021-01-13  5150820    BG-17E10-40EN
# 1     D49  X66 2021-01-05 2021-04-28   2021-03-05  5150870    BG-19E10-10EN
# 2     D49  X20 2021-01-05 2021-02-17   2021-02-19  5151400  BT192220EN-Y240
# 3     D49  X66 2021-01-05 2021-07-31   2021-01-21  5151360    F2-660320-013
# 4     D49  F45 2021-01-05 2021-01-15   2021-01-12  5151430   M10-660174-13B
# ...   ...  ...        ...        ...          ...      ...              ...
# 7142  D49  F45 2022-04-18 2022-04-27   2022-04-26  2984060    21-091071-024
# 7173  D49  F46 2022-04-20 2022-04-25   2022-04-28  3003320    21-113597-024
# 7174  D49  P56 2022-04-20 2021-11-04   2022-04-29  3003030    21-121263-001
# 7239  D49  P57 2022-04-26 2022-04-26   2022-04-26  3049320   SF7-777880-011
# 7271  D49  P56 2022-04-27 2022-05-27   2022-04-28  3064940  SFZBR152212AH21
#
#       ORIG QTY  QTY TO STOCK  QTY SCRAP  ... SCH DT CHG CNT created_yr  \
# 0         27.0          22.0        4.0  ...            0.0         21
# 1         50.0          30.0       10.0  ...            0.0         21
# 2         50.0          44.0        6.0  ...            1.0         21
# 3         80.0          23.0       64.0  ...            1.0         21
# 4        250.0         252.0        1.0  ...            0.0         21
# ...        ...           ...        ...  ...            ...        ...
# 7142     100.0         100.0        0.0  ...            0.0         22
# 7173      30.0          30.0        1.0  ...            0.0         22
# 7174     150.0         150.0        0.0  ...            0.0         22
# 7239      23.0           0.0        0.0  ...            0.0         22
# 7271      55.0          55.0        0.0  ...            0.0         22
#
#       created_wk Days Late Days Late Int  Possible_time Total Hrs single_week  \
# 0              1   22 days          22.0          -14.0  9907.000    3406.000
# 1              1  -54 days         -54.0          113.0  9907.000    3406.000
# 2              1    2 days           2.0           43.0  9907.000    3406.000
# 3              1 -191 days        -191.0          207.0  9907.000    3406.000
# 4              1   -3 days          -3.0           10.0  9907.000    3406.000
# ...          ...       ...           ...            ...       ...         ...
# 7142          16   -1 days          -1.0            9.0  6037.460    2528.574
# 7173          16    3 days           3.0            5.0  6037.460    2528.574
# 7174          16  176 days         176.0         -167.0  6037.460    2528.574
# 7239          17    0 days           0.0            0.0  6708.414    2732.230
# 7271          17  -29 days         -29.0           30.0  6708.414    2732.230
#
#      avg_output  wks_load
# 0        2006.0  4.938684
# 1        2006.0  4.938684
# 2        2006.0  4.938684
# 3        2006.0  4.938684
# 4        2006.0  4.938684
# ...         ...       ...
# 7142     2051.0  2.943667
# 7173     2051.0  2.943667
# 7174     2051.0  2.943667
# 7239     2051.0  3.270802
# 7271     2051.0  3.270802
#
# [6738 rows x 25 columns]

# %%
new_df1['B/P'].unique()
# Out:
# array(['X67', 'X66', 'X20', 'F45', 'F46', 'P55', 'P59', 'P57', 'P56',
#        'XRS', '546', 'X65', '544', 'P58', '549', '545', '548', 'FMA',
#        'XPS', 'XOS', 'P52', 'M23', 'P85', 'P81', 'L41', 'X31'],
#       dtype=object)

# %%
new_df1['PRIMARY WC'].unique()
# Out:
# array(['X5167', 'X5163', 'X5185', 'X5184', 'F5184', 'X5123', 'F5176',
#        'F5173', 'P5155', 'G3015', 'P5116', 'P5128', 'X5182', 'X5160',
#        'G3041', 'X5186', 'X5120', 'X5162', 'F5157', 'G3017', 'P5207',
#        'F5172', 'G3002', 'G3010', 'P5115', 'F5171', 'S2803', 'P5117',
#        'S2808', nan, 'P5321', 'F5159', 'G3026', 'II660', 'P5159', 'II281',
#        'F5189', 'X5180'], dtype=object)

# %% [markdown]
# ## Providing a baseline ML model now

# %%
conditions = [
    (new_df1['Days Late Int'] < 0),
    (new_df1['Days Late Int'] >= 0)]

values = [0, 1]

new_df1['Late'] = np.select(conditions, values)
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/3189421772.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df1['Late'] = np.select(conditions, values)

# %%
new_df1
# Out:
#      DEPT  B/P    CREATED     DUE DT DT COMPLETED   WO NBR      PART NUMBER  \
# 0     D49  X67 2021-01-05 2020-12-22   2021-01-13  5150820    BG-17E10-40EN
# 1     D49  X66 2021-01-05 2021-04-28   2021-03-05  5150870    BG-19E10-10EN
# 2     D49  X20 2021-01-05 2021-02-17   2021-02-19  5151400  BT192220EN-Y240
# 3     D49  X66 2021-01-05 2021-07-31   2021-01-21  5151360    F2-660320-013
# 4     D49  F45 2021-01-05 2021-01-15   2021-01-12  5151430   M10-660174-13B
# ...   ...  ...        ...        ...          ...      ...              ...
# 7142  D49  F45 2022-04-18 2022-04-27   2022-04-26  2984060    21-091071-024
# 7173  D49  F46 2022-04-20 2022-04-25   2022-04-28  3003320    21-113597-024
# 7174  D49  P56 2022-04-20 2021-11-04   2022-04-29  3003030    21-121263-001
# 7239  D49  P57 2022-04-26 2022-04-26   2022-04-26  3049320   SF7-777880-011
# 7271  D49  P56 2022-04-27 2022-05-27   2022-04-28  3064940  SFZBR152212AH21
#
#       ORIG QTY  QTY TO STOCK  QTY SCRAP  ... created_yr created_wk  Days Late  \
# 0         27.0          22.0        4.0  ...         21          1    22 days
# 1         50.0          30.0       10.0  ...         21          1   -54 days
# 2         50.0          44.0        6.0  ...         21          1     2 days
# 3         80.0          23.0       64.0  ...         21          1  -191 days
# 4        250.0         252.0        1.0  ...         21          1    -3 days
# ...        ...           ...        ...  ...        ...        ...        ...
# 7142     100.0         100.0        0.0  ...         22         16    -1 days
# 7173      30.0          30.0        1.0  ...         22         16     3 days
# 7174     150.0         150.0        0.0  ...         22         16   176 days
# 7239      23.0           0.0        0.0  ...         22         17     0 days
# 7271      55.0          55.0        0.0  ...         22         17   -29 days
#
#      Days Late Int Possible_time  Total Hrs single_week avg_output  wks_load  \
# 0             22.0         -14.0   9907.000    3406.000     2006.0  4.938684
# 1            -54.0         113.0   9907.000    3406.000     2006.0  4.938684
# 2              2.0          43.0   9907.000    3406.000     2006.0  4.938684
# 3           -191.0         207.0   9907.000    3406.000     2006.0  4.938684
# 4             -3.0          10.0   9907.000    3406.000     2006.0  4.938684
# ...            ...           ...        ...         ...        ...       ...
# 7142          -1.0           9.0   6037.460    2528.574     2051.0  2.943667
# 7173           3.0           5.0   6037.460    2528.574     2051.0  2.943667
# 7174         176.0        -167.0   6037.460    2528.574     2051.0  2.943667
# 7239           0.0           0.0   6708.414    2732.230     2051.0  3.270802
# 7271         -29.0          30.0   6708.414    2732.230     2051.0  3.270802
#
#       Late
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
# ...    ...
# 7142     0
# 7173     1
# 7174     1
# 7239     1
# 7271     0
#
# [6738 rows x 26 columns]

# %% [markdown]
# ## Merge manufacturing code

# %% [markdown]
# ### upload_4_29 is the most up to date manu code list

# %%
manu_codes=pd.read_excel('upload_4_29.xls')

# %%
manu_codes
# Out:
#         CO    PART NUMBER PART TYPE PART SUB TYPE PART SIZE  \
# 0      100   AN960JD1816L       NaN           NaN       NaN
# 1      100   AN960JD2616L       NaN           NaN       NaN
# 2      100  AR-109161-03B         S             Z        ZZ
# 3      100  AR-139131-004       NaN           NaN       NaN
# 4      100  AR-140000-008         H             Z        ZZ
# ...    ...            ...       ...           ...       ...
# 34795  100  10-667428-40B         S             B        40
# 34796  100  10-564863-36B         S             Z        36
# 34797  100  SF-114564-179         S             Z        17
# 34798  100  47-098485-007         S             B        ZZ
# 34799  100  21-121026-12B         S             R        12
#
#       PART FAMILY SERIES  PART FRONT FEATURES  PART BACK FEATURES  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                      Y                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4                      Y                  NaN                 NaN
# ...                  ...                  ...                 ...
# 34795                  G                  NaN                 NaN
# 34796                  Z                  NaN                 NaN
# 34797                  Y                  NaN                 NaN
# 34798                  Y                  NaN                 NaN
# 34799                  Y                  NaN                 NaN
#
#       RAW MATERIAL TYPE RAW MATERIAL SHAPE  RAW SIZE  SECOND RAW MAT DIM
# 0                   NaN                NaN       0.0                 0.0
# 1                   NaN                NaN       0.0                 0.0
# 2                     A                  Z       0.0                 0.0
# 3                   NaN                NaN       0.0                 0.0
# 4                     A                  H       1.0                 0.0
# ...                 ...                ...       ...                 ...
# 34795                 A                  C       0.0                 0.0
# 34796                 A                  U       0.0                 0.0
# 34797                 A                  F       0.0                 0.0
# 34798                 B                  C       0.0                 0.0
# 34799                 3                  C       0.0                 0.0
#
# [34800 rows x 12 columns]

# %%
new_df2 = pd.merge(new_df1, manu_codes, how="left", on="PART NUMBER")

# %%
new_df2
# Out:
#      DEPT  B/P    CREATED     DUE DT DT COMPLETED   WO NBR      PART NUMBER  \
# 0     D49  X67 2021-01-05 2020-12-22   2021-01-13  5150820    BG-17E10-40EN
# 1     D49  X66 2021-01-05 2021-04-28   2021-03-05  5150870    BG-19E10-10EN
# 2     D49  X20 2021-01-05 2021-02-17   2021-02-19  5151400  BT192220EN-Y240
# 3     D49  X66 2021-01-05 2021-07-31   2021-01-21  5151360    F2-660320-013
# 4     D49  F45 2021-01-05 2021-01-15   2021-01-12  5151430   M10-660174-13B
# ...   ...  ...        ...        ...          ...      ...              ...
# 6733  D49  F45 2022-04-18 2022-04-27   2022-04-26  2984060    21-091071-024
# 6734  D49  F46 2022-04-20 2022-04-25   2022-04-28  3003320    21-113597-024
# 6735  D49  P56 2022-04-20 2021-11-04   2022-04-29  3003030    21-121263-001
# 6736  D49  P57 2022-04-26 2022-04-26   2022-04-26  3049320   SF7-777880-011
# 6737  D49  P56 2022-04-27 2022-05-27   2022-04-28  3064940  SFZBR152212AH21
#
#       ORIG QTY  QTY TO STOCK  QTY SCRAP  ... PART TYPE PART SUB TYPE  \
# 0         27.0          22.0        4.0  ...         S             R
# 1         50.0          30.0       10.0  ...         S             R
# 2         50.0          44.0        6.0  ...         S             R
# 3         80.0          23.0       64.0  ...         S             P
# 4        250.0         252.0        1.0  ...         H             J
# ...        ...           ...        ...  ...       ...           ...
# 6733     100.0         100.0        0.0  ...         H             G
# 6734      30.0          30.0        1.0  ...         H             G
# 6735     150.0         150.0        0.0  ...         S             B
# 6736      23.0           0.0        0.0  ...         S             R
# 6737      55.0          55.0        0.0  ...         S             R
#
#       PART SIZE PART FAMILY SERIES PART FRONT FEATURES  PART BACK FEATURES  \
# 0            10                  P                 NaN                 NaN
# 1            10                  P                 NaN                 NaN
# 2            22                  P                 NaN                 NaN
# 3            13                  L                 NaN                 NaN
# 4            13                  T                 NaN                 NaN
# ...         ...                ...                 ...                 ...
# 6733         24                  Y                 NaN                 NaN
# 6734         24                  Y                 NaN                 NaN
# 6735         ZZ                  Y                 NaN                 NaN
# 6736         11                  B                 NaN                 NaN
# 6737         22                  P                 NaN                 NaN
#
#      RAW MATERIAL TYPE RAW MATERIAL SHAPE RAW SIZE  SECOND RAW MAT DIM
# 0                    Z                  Z     0.00                 0.0
# 1                    3                  C     1.25                 0.0
# 2                    3                  C     2.25                 0.0
# 3                    A                  C     1.00                 0.0
# 4                    A                  C     1.50                 0.0
# ...                ...                ...      ...                 ...
# 6733                 P                  C     1.50                 0.0
# 6734                 3                  C     1.50                 0.0
# 6735                 W                  C     0.75                 0.0
# 6736                 A                  C     1.50                 0.0
# 6737                 A                  C     2.25                 0.0
#
# [6738 rows x 37 columns]

# %% [markdown]
# ### rather than encoding the raw sizes by each dimension, I will batch them into size groups

# %% [markdown]
# ### need to drop the scrap qty because that can't be determined before order creation...

# %%
new_df2=new_df2.drop(columns=['DEPT', 'SECOND RAW MAT DIM', 'PART BACK FEATURES', 'PART FRONT FEATURES', 
                              'QTY SCRAP', 'CREATED BY', 'WOTYPE', 'ORIG QTY', 'QTY TO STOCK', 
                              'PART NUMBER', 'CO', 'ITEM DESC'])

# %%
new_df2
# Out:
#       B/P    CREATED     DUE DT DT COMPLETED   WO NBR   STS PRIMARY WC  \
# 0     X67 2021-01-05 2020-12-22   2021-01-13  5150820  75.0      X5167
# 1     X66 2021-01-05 2021-04-28   2021-03-05  5150870  75.0      X5163
# 2     X20 2021-01-05 2021-02-17   2021-02-19  5151400  70.0      X5185
# 3     X66 2021-01-05 2021-07-31   2021-01-21  5151360  70.0      X5184
# 4     F45 2021-01-05 2021-01-15   2021-01-12  5151430  70.0      F5184
# ...   ...        ...        ...          ...      ...   ...        ...
# 6733  F45 2022-04-18 2022-04-27   2022-04-26  2984060  50.0      F5173
# 6734  F46 2022-04-20 2022-04-25   2022-04-28  3003320  50.0      F5176
# 6735  P56 2022-04-20 2021-11-04   2022-04-29  3003030  50.0      P5128
# 6736  P57 2022-04-26 2022-04-26   2022-04-26  3049320  50.0      P5116
# 6737  P56 2022-04-27 2022-05-27   2022-04-28  3064940  50.0      P5128
#
#       SCH DT CHG CNT created_yr created_wk  ... avg_output  wks_load  Late  \
# 0                0.0         21          1  ...     2006.0  4.938684     1
# 1                0.0         21          1  ...     2006.0  4.938684     0
# 2                1.0         21          1  ...     2006.0  4.938684     1
# 3                1.0         21          1  ...     2006.0  4.938684     0
# 4                0.0         21          1  ...     2006.0  4.938684     0
# ...              ...        ...        ...  ...        ...       ...   ...
# 6733             0.0         22         16  ...     2051.0  2.943667     0
# 6734             0.0         22         16  ...     2051.0  2.943667     1
# 6735             0.0         22         16  ...     2051.0  2.943667     1
# 6736             0.0         22         17  ...     2051.0  3.270802     1
# 6737             0.0         22         17  ...     2051.0  3.270802     0
#
#       PART TYPE  PART SUB TYPE  PART SIZE  PART FAMILY SERIES  \
# 0             S              R         10                   P
# 1             S              R         10                   P
# 2             S              R         22                   P
# 3             S              P         13                   L
# 4             H              J         13                   T
# ...         ...            ...        ...                 ...
# 6733          H              G         24                   Y
# 6734          H              G         24                   Y
# 6735          S              B         ZZ                   Y
# 6736          S              R         11                   B
# 6737          S              R         22                   P
#
#       RAW MATERIAL TYPE RAW MATERIAL SHAPE RAW SIZE
# 0                     Z                  Z     0.00
# 1                     3                  C     1.25
# 2                     3                  C     2.25
# 3                     A                  C     1.00
# 4                     A                  C     1.50
# ...                 ...                ...      ...
# 6733                  P                  C     1.50
# 6734                  3                  C     1.50
# 6735                  W                  C     0.75
# 6736                  A                  C     1.50
# 6737                  A                  C     2.25
#
# [6738 rows x 25 columns]

# %%
new_df2=new_df2.drop(columns=['CREATED', 'DUE DT', 'DT COMPLETED', 'Days Late', 
                              'created_yr', 'created_wk', 'SCH DT CHG CNT', 'STS'])

# %%
new_df2
# Out:
#       B/P   WO NBR PRIMARY WC  Days Late Int  Possible_time  Total Hrs  \
# 0     X67  5150820      X5167           22.0          -14.0   9907.000
# 1     X66  5150870      X5163          -54.0          113.0   9907.000
# 2     X20  5151400      X5185            2.0           43.0   9907.000
# 3     X66  5151360      X5184         -191.0          207.0   9907.000
# 4     F45  5151430      F5184           -3.0           10.0   9907.000
# ...   ...      ...        ...            ...            ...        ...
# 6733  F45  2984060      F5173           -1.0            9.0   6037.460
# 6734  F46  3003320      F5176            3.0            5.0   6037.460
# 6735  P56  3003030      P5128          176.0         -167.0   6037.460
# 6736  P57  3049320      P5116            0.0            0.0   6708.414
# 6737  P56  3064940      P5128          -29.0           30.0   6708.414
#
#       single_week  avg_output  wks_load  Late PART TYPE PART SUB TYPE  \
# 0        3406.000      2006.0  4.938684     1         S             R
# 1        3406.000      2006.0  4.938684     0         S             R
# 2        3406.000      2006.0  4.938684     1         S             R
# 3        3406.000      2006.0  4.938684     0         S             P
# 4        3406.000      2006.0  4.938684     0         H             J
# ...           ...         ...       ...   ...       ...           ...
# 6733     2528.574      2051.0  2.943667     0         H             G
# 6734     2528.574      2051.0  2.943667     1         H             G
# 6735     2528.574      2051.0  2.943667     1         S             B
# 6736     2732.230      2051.0  3.270802     1         S             R
# 6737     2732.230      2051.0  3.270802     0         S             R
#
#      PART SIZE PART FAMILY SERIES RAW MATERIAL TYPE RAW MATERIAL SHAPE  \
# 0           10                  P                 Z                  Z
# 1           10                  P                 3                  C
# 2           22                  P                 3                  C
# 3           13                  L                 A                  C
# 4           13                  T                 A                  C
# ...        ...                ...               ...                ...
# 6733        24                  Y                 P                  C
# 6734        24                  Y                 3                  C
# 6735        ZZ                  Y                 W                  C
# 6736        11                  B                 A                  C
# 6737        22                  P                 A                  C
#
#       RAW SIZE
# 0         0.00
# 1         1.25
# 2         2.25
# 3         1.00
# 4         1.50
# ...        ...
# 6733      1.50
# 6734      1.50
# 6735      0.75
# 6736      1.50
# 6737      2.25
#
# [6738 rows x 17 columns]

# %%
conditions = [
    (new_df2['RAW SIZE'] ==0),
    (new_df2['RAW SIZE'] <= 1),
    (new_df2['RAW SIZE'] <= 2),
    (new_df2['RAW SIZE'] <= 4),
    (new_df2['RAW SIZE'] <= 6),
]

values = ['unknown','a','b','c','d']

new_df2['Raw_group'] = np.select(conditions, values)

# %%
new_df2
# Out:
#       B/P   WO NBR PRIMARY WC  Days Late Int  Possible_time  Total Hrs  \
# 0     X67  5150820      X5167           22.0          -14.0   9907.000
# 1     X66  5150870      X5163          -54.0          113.0   9907.000
# 2     X20  5151400      X5185            2.0           43.0   9907.000
# 3     X66  5151360      X5184         -191.0          207.0   9907.000
# 4     F45  5151430      F5184           -3.0           10.0   9907.000
# ...   ...      ...        ...            ...            ...        ...
# 6733  F45  2984060      F5173           -1.0            9.0   6037.460
# 6734  F46  3003320      F5176            3.0            5.0   6037.460
# 6735  P56  3003030      P5128          176.0         -167.0   6037.460
# 6736  P57  3049320      P5116            0.0            0.0   6708.414
# 6737  P56  3064940      P5128          -29.0           30.0   6708.414
#
#       single_week  avg_output  wks_load  Late PART TYPE PART SUB TYPE  \
# 0        3406.000      2006.0  4.938684     1         S             R
# 1        3406.000      2006.0  4.938684     0         S             R
# 2        3406.000      2006.0  4.938684     1         S             R
# 3        3406.000      2006.0  4.938684     0         S             P
# 4        3406.000      2006.0  4.938684     0         H             J
# ...           ...         ...       ...   ...       ...           ...
# 6733     2528.574      2051.0  2.943667     0         H             G
# 6734     2528.574      2051.0  2.943667     1         H             G
# 6735     2528.574      2051.0  2.943667     1         S             B
# 6736     2732.230      2051.0  3.270802     1         S             R
# 6737     2732.230      2051.0  3.270802     0         S             R
#
#      PART SIZE PART FAMILY SERIES RAW MATERIAL TYPE RAW MATERIAL SHAPE  \
# 0           10                  P                 Z                  Z
# 1           10                  P                 3                  C
# 2           22                  P                 3                  C
# 3           13                  L                 A                  C
# 4           13                  T                 A                  C
# ...        ...                ...               ...                ...
# 6733        24                  Y                 P                  C
# 6734        24                  Y                 3                  C
# 6735        ZZ                  Y                 W                  C
# 6736        11                  B                 A                  C
# 6737        22                  P                 A                  C
#
#       RAW SIZE Raw_group
# 0         0.00   unknown
# 1         1.25         b
# 2         2.25         c
# 3         1.00         a
# 4         1.50         b
# ...        ...       ...
# 6733      1.50         b
# 6734      1.50         b
# 6735      0.75         a
# 6736      1.50         b
# 6737      2.25         c
#
# [6738 rows x 18 columns]

# %%
new_df2=new_df2.drop(columns=['PART SIZE'])

# %%
new_df2=new_df2.drop(columns=['Days Late Int'])

# %%
new_df2=new_df2.drop(columns=['RAW SIZE'])

# %%
### dropping part size but come back to that later on
## need to drop the days late in and make WO the index

# %%
new_df2
# Out:
#       B/P   WO NBR PRIMARY WC  Possible_time  Total Hrs  single_week  \
# 0     X67  5150820      X5167          -14.0   9907.000     3406.000
# 1     X66  5150870      X5163          113.0   9907.000     3406.000
# 2     X20  5151400      X5185           43.0   9907.000     3406.000
# 3     X66  5151360      X5184          207.0   9907.000     3406.000
# 4     F45  5151430      F5184           10.0   9907.000     3406.000
# ...   ...      ...        ...            ...        ...          ...
# 6733  F45  2984060      F5173            9.0   6037.460     2528.574
# 6734  F46  3003320      F5176            5.0   6037.460     2528.574
# 6735  P56  3003030      P5128         -167.0   6037.460     2528.574
# 6736  P57  3049320      P5116            0.0   6708.414     2732.230
# 6737  P56  3064940      P5128           30.0   6708.414     2732.230
#
#       avg_output  wks_load  Late PART TYPE PART SUB TYPE PART FAMILY SERIES  \
# 0         2006.0  4.938684     1         S             R                  P
# 1         2006.0  4.938684     0         S             R                  P
# 2         2006.0  4.938684     1         S             R                  P
# 3         2006.0  4.938684     0         S             P                  L
# 4         2006.0  4.938684     0         H             J                  T
# ...          ...       ...   ...       ...           ...                ...
# 6733      2051.0  2.943667     0         H             G                  Y
# 6734      2051.0  2.943667     1         H             G                  Y
# 6735      2051.0  2.943667     1         S             B                  Y
# 6736      2051.0  3.270802     1         S             R                  B
# 6737      2051.0  3.270802     0         S             R                  P
#
#      RAW MATERIAL TYPE RAW MATERIAL SHAPE Raw_group
# 0                    Z                  Z   unknown
# 1                    3                  C         b
# 2                    3                  C         c
# 3                    A                  C         a
# 4                    A                  C         b
# ...                ...                ...       ...
# 6733                 P                  C         b
# 6734                 3                  C         b
# 6735                 W                  C         a
# 6736                 A                  C         b
# 6737                 A                  C         c
#
# [6738 rows x 15 columns]

# %%
new_df2=new_df2.set_index('WO NBR')

# %%
new_df2
# Out:
#          B/P PRIMARY WC  Possible_time  Total Hrs  single_week  avg_output  \
# WO NBR
# 5150820  X67      X5167          -14.0   9907.000     3406.000      2006.0
# 5150870  X66      X5163          113.0   9907.000     3406.000      2006.0
# 5151400  X20      X5185           43.0   9907.000     3406.000      2006.0
# 5151360  X66      X5184          207.0   9907.000     3406.000      2006.0
# 5151430  F45      F5184           10.0   9907.000     3406.000      2006.0
# ...      ...        ...            ...        ...          ...         ...
# 2984060  F45      F5173            9.0   6037.460     2528.574      2051.0
# 3003320  F46      F5176            5.0   6037.460     2528.574      2051.0
# 3003030  P56      P5128         -167.0   6037.460     2528.574      2051.0
# 3049320  P57      P5116            0.0   6708.414     2732.230      2051.0
# 3064940  P56      P5128           30.0   6708.414     2732.230      2051.0
#
#          wks_load  Late PART TYPE PART SUB TYPE PART FAMILY SERIES  \
# WO NBR
# 5150820  4.938684     1         S             R                  P
# 5150870  4.938684     0         S             R                  P
# 5151400  4.938684     1         S             R                  P
# 5151360  4.938684     0         S             P                  L
# 5151430  4.938684     0         H             J                  T
# ...           ...   ...       ...           ...                ...
# 2984060  2.943667     0         H             G                  Y
# 3003320  2.943667     1         H             G                  Y
# 3003030  2.943667     1         S             B                  Y
# 3049320  3.270802     1         S             R                  B
# 3064940  3.270802     0         S             R                  P
#
#         RAW MATERIAL TYPE RAW MATERIAL SHAPE Raw_group
# WO NBR
# 5150820                 Z                  Z   unknown
# 5150870                 3                  C         b
# 5151400                 3                  C         c
# 5151360                 A                  C         a
# 5151430                 A                  C         b
# ...                   ...                ...       ...
# 2984060                 P                  C         b
# 3003320                 3                  C         b
# 3003030                 W                  C         a
# 3049320                 A                  C         b
# 3064940                 A                  C         c
#
# [6738 rows x 14 columns]

# %%
new_df2= new_df2[new_df2['PART TYPE'].notna()]
new_df2= new_df2[new_df2['PRIMARY WC'].notna()]
new_df2= new_df2[new_df2['Total Hrs'].notna()]

# %%
new_df2.to_excel('nan_check.xls')
# Out:
# C:\Users\MPERSO~1\AppData\Local\Temp/ipykernel_16564/2313318500.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   new_df2.to_excel('nan_check.xls')

# %%
model_data=new_df2

# %% [markdown]
# ## B/P will get encoded
# ## primary WC will get encoded
# ## Work order number needs to become the index and seperate df of wo and part number needs to be created
#
# ## all dates will need to be removed and everything will need to become a number of days reference

# %%
better_model2 = model_data[model_data['Possible_time'] >= 0] 
better_model3 = better_model2[better_model2['Possible_time'] <= 40]

# %%
model_data=better_model3

# %%
# D49.to_excel('check2.xls')

# %%
encoder = ce.OneHotEncoder(use_cat_names=True)

# %%
y=model_data['Late']

# %%
X=model_data.drop('Late', axis='columns')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
print('Train', X_train.shape, y_train.shape)
print('Test', X_test.shape, y_test.shape)
# Out:
# Train (2234, 13) (2234,)
# Test (559, 13) (559,)

# %%
encoder.fit(X_train)
X_train_enc = encoder.transform(X_train)
X_test_enc = encoder.transform(X_test)

# %%
print(X_train_enc)
# Out:
#          B/P_P56  B/P_P57  B/P_X20  B/P_X65  B/P_P58  B/P_F46  B/P_X66  \
# WO NBR
# 5683030        1        0        0        0        0        0        0
# 6648200        0        1        0        0        0        0        0
# 6425430        0        0        1        0        0        0        0
# 2200390        0        1        0        0        0        0        0
# 2085820        0        0        0        1        0        0        0
# ...          ...      ...      ...      ...      ...      ...      ...
# 2824280        0        0        0        0        0        0        1
# 6140570        0        0        0        1        0        0        0
# 6366660        0        0        0        0        0        0        0
# 5438110        0        0        0        0        0        0        0
# 6322720        0        1        0        0        0        0        0
#
#          B/P_548  B/P_X67  B/P_XRS  ...  RAW MATERIAL SHAPE_C  \
# WO NBR                              ...
# 5683030        0        0        0  ...                     1
# 6648200        0        0        0  ...                     1
# 6425430        0        0        0  ...                     1
# 2200390        0        0        0  ...                     1
# 2085820        0        0        0  ...                     1
# ...          ...      ...      ...  ...                   ...
# 2824280        0        0        0  ...                     1
# 6140570        0        0        0  ...                     1
# 6366660        0        0        1  ...                     0
# 5438110        0        0        1  ...                     0
# 6322720        0        0        0  ...                     1
#
#          RAW MATERIAL SHAPE_F  RAW MATERIAL SHAPE_H  RAW MATERIAL SHAPE_Z  \
# WO NBR
# 5683030                     0                     0                     0
# 6648200                     0                     0                     0
# 6425430                     0                     0                     0
# 2200390                     0                     0                     0
# 2085820                     0                     0                     0
# ...                       ...                   ...                   ...
# 2824280                     0                     0                     0
# 6140570                     0                     0                     0
# 6366660                     0                     0                     1
# 5438110                     0                     0                     1
# 6322720                     0                     0                     0
#
#          RAW MATERIAL SHAPE_U  Raw_group_b  Raw_group_a  Raw_group_c  \
# WO NBR
# 5683030                     0            1            0            0
# 6648200                     0            1            0            0
# 6425430                     0            0            1            0
# 2200390                     0            1            0            0
# 2085820                     0            1            0            0
# ...                       ...          ...          ...          ...
# 2824280                     0            1            0            0
# 6140570                     0            1            0            0
# 6366660                     0            0            0            0
# 5438110                     0            0            0            0
# 6322720                     0            1            0            0
#
#          Raw_group_unknown  Raw_group_d
# WO NBR
# 5683030                  0            0
# 6648200                  0            0
# 6425430                  0            0
# 2200390                  0            0
# 2085820                  0            0
# ...                    ...          ...
# 2824280                  0            0
# 6140570                  0            0
# 6366660                  1            0
# 5438110                  1            0
# 6322720                  0            0
#
# [2234 rows x 126 columns]

# %%
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
print(RandomForestClassifier())
print(RandomForestRegressor())
# Out:
# RandomForestClassifier()
# RandomForestRegressor()

# %%
rfc = RandomForestClassifier()
parameters = {
    "n_estimators":[5,10,50,100,250],
    "max_depth":[2,4,8,16,32,None]
    
}

# %%
from sklearn.model_selection import GridSearchCV
cv = GridSearchCV(rfc,parameters,cv=5)
cv.fit(X_train_enc,y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 4, 8, 16, 32, None],
#                          'n_estimators': [5, 10, 50, 100, 250]})

# %%
def display(results):
    print(f'Best parameters are: {results.best_params_}')
    print("\n")
    mean_score = results.cv_results_['mean_test_score']
    std_score = results.cv_results_['std_test_score']
    params = results.cv_results_['params']
    for mean,std,params in zip(mean_score,std_score,params):
        print(f'{round(mean,3)} + or -{round(std,3)} for the {params}')

# %%
display(cv)
# Out:
# Best parameters are: {'max_depth': None, 'n_estimators': 50}
#
#
# 0.682 + or -0.005 for the {'max_depth': 2, 'n_estimators': 5}
# 0.682 + or -0.001 for the {'max_depth': 2, 'n_estimators': 10}
# 0.682 + or -0.001 for the {'max_depth': 2, 'n_estimators': 50}
# 0.682 + or -0.001 for the {'max_depth': 2, 'n_estimators': 100}
# 0.682 + or -0.001 for the {'max_depth': 2, 'n_estimators': 250}
# 0.689 + or -0.011 for the {'max_depth': 4, 'n_estimators': 5}
# 0.686 + or -0.004 for the {'max_depth': 4, 'n_estimators': 10}
# 0.684 + or -0.006 for the {'max_depth': 4, 'n_estimators': 50}
# 0.685 + or -0.004 for the {'max_depth': 4, 'n_estimators': 100}
# 0.684 + or -0.007 for the {'max_depth': 4, 'n_estimators': 250}
# 0.704 + or -0.021 for the {'max_depth': 8, 'n_estimators': 5}
# 0.703 + or -0.01 for the {'max_depth': 8, 'n_estimators': 10}
# 0.703 + or -0.013 for the {'max_depth': 8, 'n_estimators': 50}
# 0.707 + or -0.012 for the {'max_depth': 8, 'n_estimators': 100}
# 0.709 + or -0.011 for the {'max_depth': 8, 'n_estimators': 250}
# 0.711 + or -0.017 for the {'max_depth': 16, 'n_estimators': 5}
# 0.727 + or -0.022 for the {'max_depth': 16, 'n_estimators': 10}
# 0.733 + or -0.02 for the {'max_depth': 16, 'n_estimators': 50}
# 0.73 + or -0.024 for the {'max_depth': 16, 'n_estimators': 100}
# 0.728 + or -0.018 for the {'max_depth': 16, 'n_estimators': 250}
# 0.697 + or -0.024 for the {'max_depth': 32, 'n_estimators': 5}
# 0.724 + or -0.016 for the {'max_depth': 32, 'n_estimators': 10}
# 0.728 + or -0.024 for the {'max_depth': 32, 'n_estimators': 50}
# 0.733 + or -0.019 for the {'max_depth': 32, 'n_estimators': 100}
# 0.728 + or -0.015 for the {'max_depth': 32, 'n_estimators': 250}
# 0.688 + or -0.014 for the {'max_depth': None, 'n_estimators': 5}
# 0.706 + or -0.017 for the {'max_depth': None, 'n_estimators': 10}
# 0.738 + or -0.024 for the {'max_depth': None, 'n_estimators': 50}
# 0.726 + or -0.02 for the {'max_depth': None, 'n_estimators': 100}
# 0.731 + or -0.017 for the {'max_depth': None, 'n_estimators': 250}

# %%
RF_model = RandomForestClassifier(n_estimators=50, oob_score=True, max_depth=16)
#, random_state=42

# %%
RF_model.fit(X_train_enc, y_train)
# Out:
# RandomForestClassifier(max_depth=16, n_estimators=50, oob_score=True)

# %%
predictions=RF_model.predict(X_test_enc)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
classification_report(y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.72      0.36      0.48       162\n           1       0.78      0.94      0.86       397\n\n    accuracy                           0.77       559\n   macro avg       0.75      0.65      0.67       559\nweighted avg       0.77      0.77      0.75       559\n'

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[ 59, 103],
#        [ 23, 374]], dtype=int64)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.774597495527728

# %%
precision_score(y_test,predictions)
# Out:
# 0.7840670859538784

# %%
recall_score(y_test,predictions)
# Out:
# 0.9420654911838791
